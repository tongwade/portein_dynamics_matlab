# %%
import sys
sys.path.append('/home/tongwade780/pdb_website/python_code/')
from charge_sasa_dssp_new import *
import os
import csv
import numpy as np
import pandas as pd
import h5py 
import time
start = time.time()
pdb_path = '/mnt/Tsunami_HHD/Tang/onebyone_clsuter/muscle_alignment_pdb/'
pdbname_file = open ('/home/tongwade780/pdb_website/all_ca_number_all_code/onechain_100clust.csv').readlines ()
next_file = []

for line in pdbname_file[0:]:
    next_file.append(line.rstrip('\r\n' + '').split(','))
real_cluster_num = 0
for cluster in range(1002,1800):
    real_cluster_num = cluster+1
    delet_file = h5py.File('/mnt/Tsunami_HHD/Tang/onebyone_clsuter/cluster_delet_pdb_index/cluster_{0}_delet_pdb_index.mat'.format(real_cluster_num),'r') 
    delet_file['delet_pdb_index']

    cluster_pdb_name = next_file[cluster]
    delet_index = delet_file['delet_pdb_index'].value.T
    cluster_pdb_name = np.asarray(cluster_pdb_name)
    cluster_pdb_name = np.delete(cluster_pdb_name,delet_index[0]-1,None)
    cluster_pdb_name = filter(None, cluster_pdb_name)
    frames = []
    problem_pdb = []
    for pdb_chain_name in cluster_pdb_name:
        pdbname= pdb_chain_name[0:4].lower()
        pdb_file = '{0}{1}'.format(pdbname,'.pdb')
        pdbPATH = os.path.join(pdb_path,pdb_file)
        
        #sasa table
        sasa_result = getSASA_final(pdbPATH)
        #dssp table
        final_dssp_table = getDSSP_final(pdbPATH)
        try:
            #pka table
            pka_final_result = getcharge_pKa(pdbPATH)
        except:
            problem_pdb.append((pdbname,'getcharge_pKa broke'))
            continue
            #load matlab data with dataframe 

        f = h5py.File('/mnt/Tsunami_HHD/Tang/onebyone_clsuter/feature_matrix_2/{0}_individual_feature.mat'.format(pdbname),'r') 

        datas = f['individual_feature'].value.T
        matlab_data = pd.DataFrame(datas,index=datas[:,0],columns=['resID','eig_vv_1','eig_vv_2','vector_1','Rank_1','vector_2',
                                                  'Rank_2','GNM_co','co_rank','entropy','rmsf_overall','pca_feature',
                                                  'eig_first','eig_sec','shannon_entropy','shannon_entropy20',
                                                  'eig5_eig1','atomic_1','atomic_3','atomic_5','ssbond_matrix',
                                                  'Polarity','charge','stand_Dcom','side_chain_length',
                                                  'ca_len','hole_ss_bond','contact_per_res','gyradius',
                                                  'phobic_percent','RMSF','RMSF_0f_bfactor','shifted_RMSF',
                                                                  'h_bond_group','intrinsicDisorder','pca_feature_2'])

        #change resID value type to int
        matlab_data['resID'] = matlab_data['resID'].astype('int')

        sasa_result.columns = ['resID','sasa']

        sasa_result['resID'] = sasa_result['resID'].astype('int')

        pka_final_result.columns = ['resID','pka_charge']
        pka_final_result['resID'] = pka_final_result['resID'].astype('int')
        final_dssp_table.columns = ['resID','dssp_result','loop_percent','sheet_percent','helix_percent']
        final_dssp_table['resID'] = final_dssp_table['resID'].replace('',np.nan, regex=True)
        final_dssp_table = final_dssp_table[~final_dssp_table['resID'].isnull()]
#         try:
#             final_dssp_table['resID'] = sasa_result['resID'].values
#         except:
#             problem_pdb.append((pdbname,'get_dssp_merge broke'))
#             continue    
        final_dssp_table['resID'] = final_dssp_table['resID'].astype('int')

        #merge matlab feature and python feature
        merged_data = matlab_data.merge(sasa_result,how = 'left',on = 'resID')

        merged_data = merged_data.merge(pka_final_result,how = 'left',on = 'resID')

        merged_data['pka_charge']=merged_data['pka_charge'].fillna(0)

        merged_data = merged_data.merge(final_dssp_table,how = 'left',on = 'resID')
        #add pdb id
        merged_data['PDB_ID'] = pdbname
        #change feature order
        change_order = ['PDB_ID','resID','atomic_1','atomic_3','atomic_5','ssbond_matrix','Polarity',
                        'eig_vv_1','eig_vv_2','vector_1','Rank_1','vector_2','Rank_2',
                        'GNM_co','co_rank','charge','stand_Dcom','side_chain_length','pka_charge',
                        'dssp_result','sasa','entropy','ca_len','hole_ss_bond','rmsf_overall',
                        'contact_per_res','gyradius','pca_feature','eig_first','eig_sec',
                        'shannon_entropy','shannon_entropy20','eig5_eig1','phobic_percent',
                        'loop_percent','h_bond_group','intrinsicDisorder','pca_feature_2','sheet_percent','helix_percent','RMSF','RMSF_0f_bfactor',
                        'shifted_RMSF']

        merged_data = merged_data[change_order]
        frames.append(merged_data)
        
    final_time = time.time()-start    
    if len(problem_pdb) == 0:
        print 'pdb_no_problem'
    else:    
        problem_pdb_data=pd.DataFrame(problem_pdb)
        problem_pdb_data.columns = ['pdbname','probelm']

        problem_pdb_data.to_csv('/home/tongwade780/pdb_website/python_code/all_cluster_problem_pdb_add_feature/problem_pdb_data_cluster_{0}.csv'.format(real_cluster_num),index= False)
    if len(frames) == 0:
        all_cluster_pdb = filter(None, next_file[cluster])

        all_cluster_pdb = pd.DataFrame(all_cluster_pdb)
        all_cluster_pdb.to_csv('/home/tongwade780/pdb_website/python_code/no_pdb_clsuter_add_feature/cluster_{0}_no_pdb.csv'.format(real_cluster_num),index = False)
            
    else:
        result = pd.concat(frames)
        result.to_csv('/home/tongwade780/pdb_website/python_code/all_cluster_feature_csv_add_feature/cluster_{0}_all_feature.csv'.format(real_cluster_num),index = False)
# Out:
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 4066 atoms and 973 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 4066 atoms and 973 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# Unexpected number (5) of atoms in residue ARG 418 A   in conformation 1A
# Unexpected number (5) of atoms in residue ARG 268 A   in conformation 1A
# Unexpected number (6) of atoms in residue LYS  88 A   in conformation 1A
# Unexpected number (6) of atoms in residue LYS 157 A   in conformation 1A
# Unexpected number (8) of atoms in residue ARG  25 A   in conformation 1A
# Missing atoms or failed protonation for HIS  14 A (HIS) -- please check the structure
# Group (HIS) for   114-  CG    14-HIS (A) [  30.752   14.271   21.414] C
# Expected 4 interaction atoms for acids, found:
#                  0- HE2    14-HIS (A) [  30.678   14.824   24.557] H
#                115- ND1    14-HIS (A) [  30.965   13.032   22.007] N
#                118- NE2    14-HIS (A) [  30.743   14.440   23.625] N
# Expected 2 interaction atoms for bases, found:
#                115- ND1    14-HIS (A) [  30.965   13.032   22.007] N
#                118- NE2    14-HIS (A) [  30.743   14.440   23.625] N
# -------------------------------------------------------------------------------------------------------
# Covalent coupling map for Conformation container 1A with 4066 atoms and 977 groups
#             HIS  14 A | GLU 178 A |
# HIS  14 A             |     X     |
# GLU 178 A       X     |           |
#
# Calculating pKas for Conformation container 1A with 4066 atoms and 977 groups
# Removing penalised groups!!!
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# Missing atoms or failed protonation for ARG  25 A (ARG) -- please check the structure
# Group (ARG) for   200-  CZ    25-ARG (A) [  47.549   23.296    7.588] C
# Expected 8 interaction atoms for acids, found:
#                201- NH1    25-ARG (A) [  46.839   24.438    7.312] N
#                202- NH2    25-ARG (A) [  48.814   23.168    7.123] N
#                199-  NE    25-ARG (A) [  45.631   23.262    7.711] N
#                  0- HH1    25-ARG (A) [  46.954   25.403    7.036] H
#                  0-HH21    25-ARG (A) [  49.104   23.678    6.300] H
#                  0-HH22    25-ARG (A) [  49.468   22.563    7.599] H
# Expected 3 interaction atoms for bases, found:
#                201- NH1    25-ARG (A) [  46.839   24.438    7.312] N
#                202- NH2    25-ARG (A) [  48.814   23.168    7.123] N
#                199-  NE    25-ARG (A) [  45.631   23.262    7.711] N
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 4101 atoms and 982 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# Missing atoms or failed protonation for ARG 418 A (ARG) -- please check the structure
# Group (ARG) for  3387-  CZ   418-ARG (A) [  31.527   35.992   66.764] C
# Expected 8 interaction atoms for acids, found:
#               3389- NH2   418-ARG (A) [  30.265   35.590   66.699] N
#               3386-  NE   418-ARG (A) [  32.253   36.085   65.657] N
#               3388- NH1   418-ARG (A) [  32.064   36.305   67.942] N
#                  0-HH21   418-ARG (A) [  29.856   35.353   65.807] H
#                  0-HH22   418-ARG (A) [  29.713   35.521   67.542] H
#                  0- HE1   418-ARG (A) [  31.845   35.848   64.764] H
#                  0- HE2   418-ARG (A) [  33.214   36.393   65.708] H
#                  0-HH11   418-ARG (A) [  31.510   36.235   68.784] H
#                  0-HH12   418-ARG (A) [  33.025   36.612   67.994] H
# Expected 3 interaction atoms for bases, found:
#               3389- NH2   418-ARG (A) [  30.265   35.590   66.699] N
#               3386-  NE   418-ARG (A) [  32.253   36.085   65.657] N
#               3388- NH1   418-ARG (A) [  32.064   36.305   67.942] N
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 4104 atoms and 982 groups
# -------------------------------------------------------------------------------------------------------
# pdb_no_problem
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# Unexpected number (5) of atoms in residue GLN 185 A   in conformation 1A
# Unexpected number (6) of atoms in residue ARG  18 A   in conformation 1A
# Unexpected number (6) of atoms in residue LYS  22 A   in conformation 1A
# Unexpected number (6) of atoms in residue LYS  26 A   in conformation 1A
# Unexpected number (6) of atoms in residue GLU 354 A   in conformation 1A
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 3500 atoms and 906 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# Unexpected number (6) of atoms in residue GLU 251 A   in conformation 1A
# Unexpected number (5) of atoms in residue LEU   1 A   in conformation 1A
# Unexpected number (8) of atoms in residue LYS 117 A   in conformation 1A
# Unexpected number (5) of atoms in residue GLU 329 A   in conformation 1A
# Unexpected number (6) of atoms in residue LYS  26 A   in conformation 1A
# Unexpected number (6) of atoms in residue LYS 330 A   in conformation 1A
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 3508 atoms and 906 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# Unexpected number (5) of atoms in residue ARG 367 A   in conformation 1A
# Unexpected number (5) of atoms in residue GLU 354 A   in conformation 1A
# Unexpected number (5) of atoms in residue LYS 330 A   in conformation 1A
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 3506 atoms and 908 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# Unexpected number (5) of atoms in residue GLN 185 A   in conformation 1A
# Unexpected number (5) of atoms in residue GLU 251 A   in conformation 1A
# Unexpected number (5) of atoms in residue LYS  26 A   in conformation 1A
# Unexpected number (5) of atoms in residue GLU 354 A   in conformation 1A
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 3507 atoms and 907 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# Unexpected number (5) of atoms in residue GLN 154 A   in conformation 1A
# Unexpected number (6) of atoms in residue GLN 185 A   in conformation 1A
# Unexpected number (5) of atoms in residue ARG 367 A   in conformation 1A
# Unexpected number (6) of atoms in residue GLU 251 A   in conformation 1A
# Unexpected number (7) of atoms in residue LYS  26 A   in conformation 1A
# Unexpected number (5) of atoms in residue LYS 330 A   in conformation 1A
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 3494 atoms and 905 groups
# -------------------------------------------------------------------------------------------------------
# pdb_no_problem
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 3761 atoms and 1006 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 3761 atoms and 1006 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 3761 atoms and 1006 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# ...
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# Missing atoms or failed protonation for GLU  63 A (BBN) -- please check the structure
# Group (BBN) for   482-   N    63-GLU (A) [  16.960   28.495   -7.125] N
# Expected 2 interaction atoms for acids, found:
#                  0-  H1    63-GLU (A) [  17.057   28.568   -6.122] H
#                  0-  H2    63-GLU (A) [  17.047   27.527   -7.402] H
#                482-   N    63-GLU (A) [  16.960   28.495   -7.125] N
# Expected 2 interaction atoms for bases, found:
#                  0-  H1    63-GLU (A) [  17.057   28.568   -6.122] H
#                  0-  H2    63-GLU (A) [  17.047   27.527   -7.402] H
#                482-   N    63-GLU (A) [  16.960   28.495   -7.125] N
# Missing atoms or failed protonation for LYS 302 A (BBN) -- please check the structure
# Group (BBN) for  2454-   N   302-LYS (A) [  29.974   34.340    2.235] N
# Expected 2 interaction atoms for acids, found:
#                  0-  H1   302-LYS (A) [  30.017   33.331    2.205] H
#                  0-  H2   302-LYS (A) [  29.096   34.651    1.845] H
#               2454-   N   302-LYS (A) [  29.974   34.340    2.235] N
# Expected 2 interaction atoms for bases, found:
#                  0-  H1   302-LYS (A) [  30.017   33.331    2.205] H
#                  0-  H2   302-LYS (A) [  29.096   34.651    1.845] H
#               2454-   N   302-LYS (A) [  29.974   34.340    2.235] N
# Missing atoms or failed protonation for ILE 327 A (BBN) -- please check the structure
# Group (BBN) for  2647-   N   327-ILE (A) [  17.686   32.536   12.219] N
# Expected 2 interaction atoms for acids, found:
#                  0-  H1   327-ILE (A) [  17.589   31.543   12.379] H
#                  0-  H2   327-ILE (A) [  16.770   32.954   12.137] H
#               2647-   N   327-ILE (A) [  17.686   32.536   12.219] N
# Expected 2 interaction atoms for bases, found:
#                  0-  H1   327-ILE (A) [  17.589   31.543   12.379] H
#                  0-  H2   327-ILE (A) [  16.770   32.954   12.137] H
#               2647-   N   327-ILE (A) [  17.686   32.536   12.219] N
# Missing atoms or failed protonation for GLU 342 A (BBN) -- please check the structure
# Group (BBN) for  2759-   N   342-GLU (A) [  25.485   37.494   19.214] N
# Expected 2 interaction atoms for acids, found:
#                  0-  H1   342-GLU (A) [  25.975   36.921   19.886] H
#                  0-  H2   342-GLU (A) [  26.154   37.981   18.635] H
#               2759-   N   342-GLU (A) [  25.485   37.494   19.214] N
# Expected 2 interaction atoms for bases, found:
#                  0-  H1   342-GLU (A) [  25.975   36.921   19.886] H
#                  0-  H2   342-GLU (A) [  26.154   37.981   18.635] H
#               2759-   N   342-GLU (A) [  25.485   37.494   19.214] N
# Missing atoms or failed protonation for GLY 391 A (BBN) -- please check the structure
# Group (BBN) for  3179-   N   391-GLY (A) [   9.081   53.164   14.048] N
# Expected 2 interaction atoms for acids, found:
#                  0-  H1   391-GLY (A) [   9.049   52.156   13.990] H
#                  0-  H2   391-GLY (A) [   9.580   53.531   13.251] H
#               3179-   N   391-GLY (A) [   9.081   53.164   14.048] N
# Expected 2 interaction atoms for bases, found:
#                  0-  H1   391-GLY (A) [   9.049   52.156   13.990] H
#                  0-  H2   391-GLY (A) [   9.580   53.531   13.251] H
#               3179-   N   391-GLY (A) [   9.081   53.164   14.048] N
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 3738 atoms and 957 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# Missing atoms or failed protonation for GLU  63 A (BBN) -- please check the structure
# Group (BBN) for   485-   N    63-GLU (A) [  17.034   28.526   -7.104] N
# Expected 2 interaction atoms for acids, found:
#                  0-  H1    63-GLU (A) [  17.124   28.591   -6.100] H
#                  0-  H2    63-GLU (A) [  17.108   27.559   -7.386] H
#                485-   N    63-GLU (A) [  17.034   28.526   -7.104] N
# Expected 2 interaction atoms for bases, found:
#                  0-  H1    63-GLU (A) [  17.124   28.591   -6.100] H
#                  0-  H2    63-GLU (A) [  17.108   27.559   -7.386] H
#                485-   N    63-GLU (A) [  17.034   28.526   -7.104] N
# Missing atoms or failed protonation for LYS 302 A (BBN) -- please check the structure
# Group (BBN) for  2455-   N   302-LYS (A) [  30.085   34.454    2.267] N
# Expected 2 interaction atoms for acids, found:
#                  0-  H1   302-LYS (A) [  30.109   33.444    2.249] H
#                  0-  H2   302-LYS (A) [  29.204   34.776    1.893] H
#               2455-   N   302-LYS (A) [  30.085   34.454    2.267] N
# Expected 2 interaction atoms for bases, found:
#                  0-  H1   302-LYS (A) [  30.109   33.444    2.249] H
#                  0-  H2   302-LYS (A) [  29.204   34.776    1.893] H
#               2455-   N   302-LYS (A) [  30.085   34.454    2.267] N
# Missing atoms or failed protonation for ILE 327 A (BBN) -- please check the structure
# Group (BBN) for  2648-   N   327-ILE (A) [  17.831   32.733   12.228] N
# Expected 2 interaction atoms for acids, found:
#                  0-  H1   327-ILE (A) [  17.727   31.744   12.402] H
#                  0-  H2   327-ILE (A) [  16.918   33.158   12.149] H
#               2648-   N   327-ILE (A) [  17.831   32.733   12.228] N
# Expected 2 interaction atoms for bases, found:
#                  0-  H1   327-ILE (A) [  17.727   31.744   12.402] H
#                  0-  H2   327-ILE (A) [  16.918   33.158   12.149] H
#               2648-   N   327-ILE (A) [  17.831   32.733   12.228] N
# Missing atoms or failed protonation for GLU 342 A (BBN) -- please check the structure
# Group (BBN) for  2760-   N   342-GLU (A) [  25.585   37.579   19.229] N
# Expected 2 interaction atoms for acids, found:
#                  0-  H1   342-GLU (A) [  26.050   37.000   19.914] H
#                  0-  H2   342-GLU (A) [  26.275   38.036   18.651] H
#               2760-   N   342-GLU (A) [  25.585   37.579   19.229] N
# Expected 2 interaction atoms for bases, found:
#                  0-  H1   342-GLU (A) [  26.050   37.000   19.914] H
#                  0-  H2   342-GLU (A) [  26.275   38.036   18.651] H
#               2760-   N   342-GLU (A) [  25.585   37.579   19.229] N
# Missing atoms or failed protonation for GLY 391 A (BBN) -- please check the structure
# Group (BBN) for  3175-   N   391-GLY (A) [   9.187   53.314   14.065] N
# Expected 2 interaction atoms for acids, found:
#                  0-  H1   391-GLY (A) [   9.152   52.307   14.002] H
#                  0-  H2   391-GLY (A) [   9.689   53.684   13.271] H
#               3175-   N   391-GLY (A) [   9.187   53.314   14.065] N
# Expected 2 interaction atoms for bases, found:
#                  0-  H1   391-GLY (A) [   9.152   52.307   14.002] H
#                  0-  H2   391-GLY (A) [   9.689   53.684   13.271] H
#               3175-   N   391-GLY (A) [   9.187   53.314   14.065] N
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 3681 atoms and 942 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-11-13
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
