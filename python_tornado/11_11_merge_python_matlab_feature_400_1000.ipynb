# %%
import sys
sys.path.append('/home/tongwade780/pdb_website/python_code/')
from charge_sasa_dssp_new import *
import os
import csv
import numpy as np
import pandas as pd
import h5py 
import time
start = time.time()
pdb_path = '/mnt/Tsunami_HHD/Tang/onebyone_clsuter/muscle_alignment_pdb/'
pdbname_file = open ('/home/tongwade780/pdb_website/all_ca_number_all_code/onechain_100clust.csv').readlines ()
next_file = []

for line in pdbname_file[0:]:
    next_file.append(line.rstrip('\r\n' + '').split(','))
real_cluster_num = 0
for cluster in range(1,2):
    real_cluster_num = cluster+1
    delet_file = h5py.File('/mnt/Tsunami_HHD/Tang/onebyone_clsuter/cluster_delet_pdb_index/cluster_{0}_delet_pdb_index.mat'.format(real_cluster_num),'r') 
    delet_file['delet_pdb_index']

    cluster_pdb_name = next_file[cluster]
    delet_index = delet_file['delet_pdb_index'].value.T
    cluster_pdb_name = np.asarray(cluster_pdb_name)
    cluster_pdb_name = np.delete(cluster_pdb_name,delet_index[0]-1,None)
    cluster_pdb_name = filter(None, cluster_pdb_name)
    frames = []
    problem_pdb = []
    for pdb_chain_name in cluster_pdb_name:
        pdbname= pdb_chain_name[0:4].lower()
        pdb_file = '{0}{1}'.format(pdbname,'.pdb')
        pdbPATH = os.path.join(pdb_path,pdb_file)
        
        #sasa table
        sasa_result = getSASA_final(pdbPATH)
        #dssp table
        final_dssp_table = getDSSP_final(pdbPATH)
        try:
            #pka table
            pka_final_result = getcharge_pKa(pdbPATH)
        except:
            problem_pdb.append((pdbname,'getcharge_pKa broke'))
            continue
            #load matlab data with dataframe 

        f = h5py.File('/mnt/Tsunami_HHD/Tang/onebyone_clsuter/feature_matrix_2/{0}_individual_feature.mat'.format(pdbname),'r') 

        datas = f['individual_feature'].value.T
        matlab_data = pd.DataFrame(datas,index=datas[:,0],columns=['resID','eig_vv_1','eig_vv_2','vector_1','Rank_1','vector_2',
                                                  'Rank_2','GNM_co','co_rank','entropy','rmsf_overall','pca_feature',
                                                  'eig_first','eig_sec','shannon_entropy','shannon_entropy20',
                                                  'eig5_eig1','atomic_1','atomic_3','atomic_5','ssbond_matrix',
                                                  'Polarity','charge','stand_Dcom','side_chain_length',
                                                  'ca_len','hole_ss_bond','contact_per_res','gyradius',
                                                  'phobic_percent','RMSF','RMSF_0f_bfactor','shifted_RMSF',
                                                                  'h_bond_group','intrinsicDisorder','pca_feature_2'])

        #change resID value type to int
        matlab_data['resID'] = matlab_data['resID'].astype('int')

        sasa_result.columns = ['resID','sasa']

        sasa_result['resID'] = sasa_result['resID'].astype('int')

        pka_final_result.columns = ['resID','pka_charge']
        pka_final_result['resID'] = pka_final_result['resID'].astype('int')
        final_dssp_table.columns = ['resID','dssp_result','loop_percent','sheet_percent','helix_percent']
        final_dssp_table['resID'] = final_dssp_table['resID'].replace('',np.nan, regex=True)
        final_dssp_table = final_dssp_table[~final_dssp_table['resID'].isnull()]
#         try:
#             final_dssp_table['resID'] = sasa_result['resID'].values
#         except:
#             problem_pdb.append((pdbname,'get_dssp_merge broke'))
#             continue    
        final_dssp_table['resID'] = final_dssp_table['resID'].astype('int')

        #merge matlab feature and python feature
        merged_data = matlab_data.merge(sasa_result,how = 'left',on = 'resID')

        merged_data = merged_data.merge(pka_final_result,how = 'left',on = 'resID')

        merged_data['pka_charge']=merged_data['pka_charge'].fillna(0)

        merged_data = merged_data.merge(final_dssp_table,how = 'left',on = 'resID')
        #add pdb id
        merged_data['PDB_ID'] = pdbname
        #change feature order
        change_order = ['PDB_ID','resID','atomic_1','atomic_3','atomic_5','ssbond_matrix','Polarity',
                        'eig_vv_1','eig_vv_2','vector_1','Rank_1','vector_2','Rank_2',
                        'GNM_co','co_rank','charge','stand_Dcom','side_chain_length','pka_charge',
                        'dssp_result','sasa','entropy','ca_len','hole_ss_bond','rmsf_overall',
                        'contact_per_res','gyradius','pca_feature','eig_first','eig_sec',
                        'shannon_entropy','shannon_entropy20','eig5_eig1','phobic_percent',
                        'loop_percent','h_bond_group','intrinsicDisorder','pca_feature_2','sheet_percent','helix_percent','RMSF','RMSF_0f_bfactor',
                        'shifted_RMSF']

        merged_data = merged_data[change_order]
        frames.append(merged_data)
        
    final_time = time.time()-start    
    if len(problem_pdb) == 0:
        print 'pdb_no_problem'
    else:    
        problem_pdb_data=pd.DataFrame(problem_pdb)
        problem_pdb_data.columns = ['pdbname','probelm']

        problem_pdb_data.to_csv('/home/tongwade780/pdb_website/python_code/all_cluster_problem_pdb_add_feature/problem_pdb_data_cluster_{0}.csv'.format(real_cluster_num),index= False)
    if len(frames) == 0:
        all_cluster_pdb = filter(None, next_file[cluster])

        all_cluster_pdb = pd.DataFrame(all_cluster_pdb)
        all_cluster_pdb.to_csv('/home/tongwade780/pdb_website/python_code/no_pdb_clsuter_add_feature/cluster_{0}_no_pdb.csv'.format(real_cluster_num),index = False)
            
    else:
        result = pd.concat(frames)
        result.to_csv('/home/tongwade780/pdb_website/python_code/all_cluster_feature_csv_add_feature/cluster_{0}_all_feature.csv'.format(real_cluster_num),index = False)
# Out:
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1226 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1225 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1226 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1226 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1226 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1226 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1226 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1226 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1226 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1226 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1226 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1226 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1226 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1226 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1226 atoms and 334 groups
# ...
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1226 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Calculating pKas for Conformation container 1A with 1225 atoms and 334 groups
# -------------------------------------------------------------------------------------------------------
# propka3.1                                                                                    2017-12-19
# -------------------------------------------------------------------------------------------------------
# --                                                                                                   --
# --                                   PROPKA: A PROTEIN PKA PREDICTOR                                 --
# --                                                                                                   --
# --                                 VERSION 1.0,  04/25/2004, IOWA CITY                               --
# --                                             BY HUI LI                                             --
# --                                                                                                   --
# --                            VERSION 2.0,  11/05/2007, IOWA CITY/COPENHAGEN                         --
# --                                BY DELPHINE C. BAS AND DAVID M. ROGERS                             --
# --                                                                                                   --
# --                                VERSION 3.0,  01/06/2011, COPENHAGEN                               --
# --                            BY MATS H.M. OLSSON AND CHRESTEN R. SONDERGARD                         --
# --                                                                                                   --
# --                                VERSION 3.1,  07/01/2011, COPENHAGEN                               --
# --                            BY CHRESTEN R. SONDERGARD AND MATS H.M. OLSSON                         --
# -------------------------------------------------------------------------------------------------------
#
#
# -------------------------------------------------------------------------------------------------------
#  References:
#
#    Very Fast Empirical Prediction and Rationalization of Protein pKa Values
#    Hui Li, Andrew D. Robertson and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 61:704-721 (2005)
#
#    Very Fast Prediction and Rationalization of pKa Values for Protein-Ligand Complexes
#    Delphine C. Bas, David M. Rogers and Jan H. Jensen
#    PROTEINS: Structure, Function, and Bioinformatics 73:765-783 (2008)
#
#    PROPKA3: Consistent Treatment of Internal and Surface Residues in Empirical pKa predictions
#    Mats H.M. Olsson, Chresten R. Sondergard, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, 7(2):525-537 (2011)
#
#    Improved Treatment of Ligands and Coupling Effects in Empirical Calculation
#     and Rationalization of pKa Values
#    Chresten R. Sondergaard, Mats H.M. Olsson, Michal Rostkowski, and Jan H. Jensen
#    Journal of Chemical Theory and Computation, (2011)
#
# -------------------------------------------------------------------------------------------------------
#
#
#
# Missing atoms or failed protonation for VAL   3 A (BBN) -- please check the structure
# Group (BBN) for    10-   N     3-VAL (A) [   2.637   12.722    7.707] N
# Expected 2 interaction atoms for acids, found:
#                 10-   N     3-VAL (A) [   2.637   12.722    7.707] N
# Expected 2 interaction atoms for bases, found:
#                 10-   N     3-VAL (A) [   2.637   12.722    7.707] N
# Missing atoms or failed protonation for ARG   6 A (BBN) -- please check the structure
# Group (BBN) for    32-   N     6-ARG (A) [  -3.494   19.841    5.054] N
# Expected 2 interaction atoms for acids, found:
#                 32-   N     6-ARG (A) [  -3.494   19.841    5.054] N
# Expected 2 interaction atoms for bases, found:
#                 32-   N     6-ARG (A) [  -3.494   19.841    5.054] N
# Missing atoms or failed protonation for GLU   8 A (BBN) -- please check the structure
# Group (BBN) for    49-   N     8-GLU (A) [  -6.856   17.666    5.685] N
# Expected 2 interaction atoms for acids, found:
#                 49-   N     8-GLU (A) [  -6.856   17.666    5.685] N
# Expected 2 interaction atoms for bases, found:
#                 49-   N     8-GLU (A) [  -6.856   17.666    5.685] N
# Missing atoms or failed protonation for LEU   9 A (BBN) -- please check the structure
# Group (BBN) for    58-   N     9-LEU (A) [  -6.196   16.941    8.212] N
# Expected 2 interaction atoms for acids, found:
#                 58-   N     9-LEU (A) [  -6.196   16.941    8.212] N
# Expected 2 interaction atoms for bases, found:
#                 58-   N     9-LEU (A) [  -6.196   16.941    8.212] N
# Missing atoms or failed protonation for ALA  10 A (BBN) -- please check the structure
# Group (BBN) for    66-   N    10-ALA (A) [  -7.581   19.116    9.160] N
# Expected 2 interaction atoms for acids, found:
#                 66-   N    10-ALA (A) [  -7.581   19.116    9.160] N
# Expected 2 interaction atoms for bases, found:
#                 66-   N    10-ALA (A) [  -7.581   19.116    9.160] N
# Missing atoms or failed protonation for ALA  12 A (BBN) -- please check the structure
# Group (BBN) for    76-   N    12-ALA (A) [ -10.217   15.820   10.739] N
# Expected 2 interaction atoms for acids, found:
#                 76-   N    12-ALA (A) [ -10.217   15.820   10.739] N
# Expected 2 interaction atoms for bases, found:
#                 76-   N    12-ALA (A) [ -10.217   15.820   10.739] N
# Missing atoms or failed protonation for HIS  16 A (BBN) -- please check the structure
# Group (BBN) for   109-   N    16-HIS (A) [ -12.525   14.832   16.424] N
# Expected 2 interaction atoms for acids, found:
#                109-   N    16-HIS (A) [ -12.525   14.832   16.424] N
# Expected 2 interaction atoms for bases, found:
#                109-   N    16-HIS (A) [ -12.525   14.832   16.424] N
# Missing atoms or failed protonation for GLY  17 A (BBN) -- please check the structure
# Group (BBN) for   119-   N    17-GLY (A) [ -13.381   16.809   18.761] N
# Expected 2 interaction atoms for acids, found:
#                119-   N    17-GLY (A) [ -13.381   16.809   18.761] N
# Expected 2 interaction atoms for bases, found:
#                119-   N    17-GLY (A) [ -13.381   16.809   18.761] N
# Missing atoms or failed protonation for GLY  27 A (BBN) -- please check the structure
# Group (BBN) for   200-   N    27-GLY (A) [  -8.965   26.433   12.760] N
# Expected 2 interaction atoms for acids, found:
#                200-   N    27-GLY (A) [  -8.965   26.433   12.760] N
# Expected 2 interaction atoms for bases, found:
#                200-   N    27-GLY (A) [  -8.965   26.433   12.760] N
# Missing atoms or failed protonation for ASN  28 A (BBN) -- please check the structure
# Group (BBN) for   204-   N    28-ASN (A) [  -7.053   27.686   14.024] N
# Expected 2 interaction atoms for acids, found:
#                204-   N    28-ASN (A) [  -7.053   27.686   14.024] N
# Expected 2 interaction atoms for bases, found:
#                204-   N    28-ASN (A) [  -7.053   27.686   14.024] N
# Missing atoms or failed protonation for VAL  30 A (BBN) -- please check the structure
# Group (BBN) for   226-   N    30-VAL (A) [  -5.076   24.192   13.266] N
# Expected 2 interaction atoms for acids, found:
#                226-   N    30-VAL (A) [  -5.076   24.192   13.266] N
# Expected 2 interaction atoms for bases, found:
#                226-   N    30-VAL (A) [  -5.076   24.192   13.266] N
# Missing atoms or failed protonation for CYS  31 A (BBN) -- please check the structure
# Group (BBN) for   233-   N    31-CYS (A) [  -3.362   25.840   11.686] N
# Expected 2 interaction atoms for acids, found:
#                233-   N    31-CYS (A) [  -3.362   25.840   11.686] N
# Expected 2 interaction atoms for bases, found:
#                233-   N    31-CYS (A) [  -3.362   25.840   11.686] N
# Missing atoms or failed protonation for ALA  32 A (BBN) -- please check the structure
# Group (BBN) for   239-   N    32-ALA (A) [  -1.318   26.104   13.645] N
# Expected 2 interaction atoms for acids, found:
#                239-   N    32-ALA (A) [  -1.318   26.104   13.645] N
# Expected 2 interaction atoms for bases, found:
#                239-   N    32-ALA (A) [  -1.318   26.104   13.645] N
# Missing atoms or failed protonation for ASN  38 A (AMD) -- please check the structure
# Group (AMD) for   289-  CG    38-ASN (A) [   5.867   21.687    7.707] C
# Expected 3 interaction atoms for acids, found:
#                291- ND2    38-ASN (A) [   6.790   21.358    7.075] N
#                  0- HD2    38-ASN (A) [   7.615   20.906    6.707] H
# Expected 1 interaction atoms for bases, found:
#                290- OD1    38-ASN (A) [   5.273   22.478    7.391] O
# Missing atoms or failed protonation for ASN  40 A (BBN) -- please check the structure
# Group (BBN) for   303-   N    40-ASN (A) [   3.296   16.941   10.107] N
# Expected 2 interaction atoms for acids, found:
#                303-   N    40-ASN (A) [   3.296   16.941   10.107] N
# Expected 2 interaction atoms for bases, found:
#                303-   N    40-ASN (A) [   3.296   16.941   10.107] N
# Missing atoms or failed protonation for GLN  42 A (BBN) -- please check the structure
# Group (BBN) for   318-   N    42-GLN (A) [   5.142   12.854   13.834] N
# Expected 2 interaction atoms for acids, found:
#                318-   N    42-GLN (A) [   5.142   12.854   13.834] N
# Expected 2 interaction atoms for bases, found:
#                318-   N    42-GLN (A) [   5.142   12.854   13.834] N
# Missing atoms or failed protonation for ASN  47 A (AMD) -- please check the structure
# Group (AMD) for   363-  CG    47-ASN (A) [  12.656   22.676   23.183] C
# Expected 3 interaction atoms for acids, found:
#                365- ND2    47-ASN (A) [  12.393   23.071   22.741] N
# Expected 1 interaction atoms for bases, found:
#                364- OD1    47-ASN (A) [  11.997   21.951   23.752] O
# Missing atoms or failed protonation for SER  51 A (BBN) -- please check the structure
# Group (BBN) for   385-   N    51-SER (A) [  14.370   18.457   28.237] N
# Expected 2 interaction atoms for acids, found:
#                385-   N    51-SER (A) [  14.370   18.457   28.237] N
# Expected 2 interaction atoms for bases, found:
#                385-   N    51-SER (A) [  14.370   18.457   28.237] N
# Missing atoms or failed protonation for THR  52 A (BBN) -- please check the structure
# Group (BBN) for   391-   N    52-THR (A) [  12.524   18.062   25.710] N
# Expected 2 interaction atoms for acids, found:
#                391-   N    52-THR (A) [  12.524   18.062   25.710] N
# Expected 2 interaction atoms for bases, found:
#                391-   N    52-THR (A) [  12.524   18.062   25.710] N
# Missing atoms or failed protonation for ASP  53 A (BBN) -- please check the structure
# Group (BBN) for   398-   N    53-ASP (A) [  10.020   17.996   22.741] N
# Expected 2 interaction atoms for acids, found:
#                398-   N    53-ASP (A) [  10.020   17.996   22.741] N
# Expected 2 interaction atoms for bases, found:
#                398-   N    53-ASP (A) [  10.020   17.996   22.741] N
# Missing atoms or failed protonation for SER  61 A (BBN) -- please check the structure
# Group (BBN) for   463-   N    61-SER (A) [   7.844   17.798   27.163] N
# Expected 2 interaction atoms for acids, found:
#                463-   N    61-SER (A) [   7.844   17.798   27.163] N
# Expected 2 interaction atoms for bases, found:
#                463-   N    61-SER (A) [   7.844   17.798   27.163] N
# Missing atoms or failed protonation for TRP  64 A (BBN) -- please check the structure
# Group (BBN) for   494-   N    64-TRP (A) [   3.757   17.666   30.195] N
# Expected 2 interaction atoms for acids, found:
#                494-   N    64-TRP (A) [   3.757   17.666   30.195] N
# Expected 2 interaction atoms for bases, found:
#                494-   N    64-TRP (A) [   3.757   17.666   30.195] N
# Missing atoms or failed protonation for GLY  68 A (BBN) -- please check the structure
# Group (BBN) for   530-   N    68-GLY (A) [  11.536    9.492   29.690] N
# Expected 2 interaction atoms for acids, found:
#                530-   N    68-GLY (A) [  11.536    9.492   29.690] N
# Expected 2 interaction atoms for bases, found:
#                530-   N    68-GLY (A) [  11.536    9.492   29.690] N
# Missing atoms or failed protonation for ARG  74 A (ARG) -- please check the structure
# Group (ARG) for   577-  CZ    74-ARG (A) [   7.185   20.494   39.810] C
# Expected 8 interaction atoms for acids, found:
#                576-  NE    74-ARG (A) [   6.762   19.228   39.600] N

# %%
sasa_result = getSASA_final(pdbPATH)
