# %%
path = '/home/tongwade780/pdb_website/python_code/all_cluster_feature_csv_add_feature/all_clusters_all_features_add_3_features.csv'
with open(path,'r') as f:
    lines = f.readlines()


header = lines[0]

new_lines = [line for line in lines if not line == lines[0]]


new_lines.insert(0,header)

text = ''.join(new_lines)

with open('/home/tongwade780/pdb_website/python_code/all_cluster_feature_csv_add_feature/all_clusters_all_features_add_3_features_new.csv','w') as r:
    r.write(text)

# %%
import time
import numpy as np
import pandas as pd
start = time.time()

# path = '/home/tongwade780/pdb_website/python_code/all_cluster_feature_csv_add_feature/all_clusters_all_features_add_3_features_new.csv'
# # with open(path,'r') as f:
# #     lines = f.readlines()
# all_data = pd.DataFrame.from_csv(path)
#all = pd.read_csv('/home/tongwade780/pdb_website/python_code/all_cluster_feature_csv_add_feature/all_clusters_all_features_add_3_features_clusterID.csv')
all = pd.read_csv('/home/tongwade780/pdb_website/python_code/all_cluster_feature_csv_add_feature/all_clusters_all_features_add_3_features_clusterID_pca_3.csv')
end = time.time()

# %%
all
# Out:
#         PDB_ID  resID  atomic_1   atomic_3  atomic_5  ssbond_matrix  Polarity  \
# 0         1k6w      1       8.0   7.500000      8.00            0.0       8.1
# 1         1k6w      2      12.0   8.000000      9.75            0.0       4.9
# 2         1k6w      3      19.0  12.666667     10.80            0.0      10.5
# 3         1k6w      4      28.0  17.333333     14.40            0.0       8.6
# 4         1k6w      5      26.0  19.666667     19.00            0.0       5.2
# 5         1k6w      6      35.0  24.333333     18.80            0.0       5.2
# 6         1k6w      7      37.0  21.666667     19.80            0.0      11.6
# 7         1k6w      8      23.0  21.333333     17.00            0.0       8.1
# 8         1k6w      9      28.0  16.000000     14.00            0.0      10.5
# 9         1k6w     10      22.0  11.000000      8.40            0.0       4.9
# 10        1k6w     11      11.0   4.666667      6.60            0.0       8.0
# ...

# %%
end-start
# Out:
# 142.4059100151062

# %%
test = all[all.PDB_ID.isin(['3rn6'])]

# %%
pca_3 = all.pca_feature.values/all.pca_feature_2.values

pca_3 = pd.DataFrame(pca_3,columns=['pca_feature_3'])

# %%
# Out:
#          pca_feature_3
# 0             0.996046
# 1             0.996046
# 2             0.996046
# 3             0.996046
# 4             0.996046
# 5             0.996046
# 6             0.996046
# 7             0.996046
# 8             0.996046
# 9             0.996046
# 10            0.996046
# 11            0.996046
# 12            0.996046
# 13            0.996046
# 14            0.996046
# 15            0.996046
# 16            0.996046
# 17            0.996046
# 18            0.996046
# 19            0.996046
# 20            0.996046
# 21            0.996046
# 22            0.996046
# 23            0.996046
# 24            0.996046
# 25            0.996046
# 26            0.996046
# 27            0.996046
# 28            0.996046
# 29            0.996046
# ...                ...
# 5934007       0.744001
# 5934008       0.744001
# 5934009       0.744001
# 5934010       0.744001
# 5934011       0.744001
# 5934012       0.744001
# 5934013       0.744001
# 5934014       0.744001
# ...

# %%
len(pca_3)
# Out:
# 5934037

# %%
len(all)
# Out:
# 5934037

# %%
all = all.join(pca_3)

# %%
change_order = ['PDB_ID','resID','atomic_1','atomic_3','atomic_5','ssbond_matrix','Polarity',
                'eig_vv_1','eig_vv_2','vector_1','Rank_1','vector_2','Rank_2',
                'GNM_co','co_rank','charge','stand_Dcom','side_chain_length','pka_charge',
                'dssp_result','sasa','entropy','ca_len','hole_ss_bond','rmsf_overall',
                'contact_per_res','gyradius','pca_feature','eig_first','eig_sec',
                'shannon_entropy','shannon_entropy20','eig5_eig1','phobic_percent',
                'loop_percent','h_bond_group','intrinsicDisorder','pca_feature_2','pca_feature_3','sheet_percent','helix_percent','RMSF','RMSF_0f_bfactor',
                'shifted_RMSF']

all = all[change_order]

# %%
all.to_csv('/home/tongwade780/pdb_website/python_code/all_cluster_feature_csv_add_feature/all_clusters_all_features_add_3_features_clusterID_pca_3.csv',index= False)
