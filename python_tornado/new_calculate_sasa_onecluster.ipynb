# %%
import os
import pandas as pd
import re
import shutil
import uuid
import subprocess
RSAColumns = ['Header','ResName','chainID','resID','All-atoms-ABS','All-atoms-REL','Total-Side-ABS','Total-Side-REL','Main-Chain-ABS','Main-Chain-REL','Non-polar-ABS','Non-polar-REL','All polar-ABS','All polar-REL']
respattern = re.compile('^RES')
naccessExec ='/opt/Naccess/naccess'
def getSASA(pdbPath):  
    # generate tmpfile name
    tmpName = str(uuid.uuid1());
    tmpFullName = tmpName + '.pdb';
    rsa_file= tmpName + '.rsa'
    
    # create tmpfile
    shutil.copy(pdbPath,os.path.join(os.curdir,tmpFullName)) # create tmpfile
    subprocess.call([naccessExec,tmpFullName])
    with open(rsa_file, 'r') as naccessData:      
        lines = naccessData.readlines()
        data = [line.strip().split() for line in lines if respattern.search(line)]  
        SASA_Data_Frame=pd.DataFrame(data,columns= RSAColumns)
        SASA_Data_Frame.drop('Header',axis=1,inplace=True)
    
    # remove tmporary files
    for fileName in os.listdir(os.curdir):
        if re.search('^%s'%tmpName,fileName):
            os.remove(fileName) 
    return SASA_Data_Frame

# %%
import os
import csv
pdb_path = '/home/tongwade780/pdb_website/onebyone_cluster_code/muscle_alignment_pdb'
pdbname_file = open ('/home/tongwade780/pdb_website/all_ca_number_all_code/onechain_100clust.csv').readlines ()
next_file = []
for line in pdbname_file[0:]:
    next_file.append(line.split(','))
cluster_1 = next_file[0]
pdbname = cluster_1[0][0:4].lower()    
pdb_file = '{0}{1}'.format(pdbname,'.pdb')
pdbPATH = os.path.join(pdb_path,pdb_file)

# %%
SASA_Data_Frame = getSASA(pdbPATH)

# %%
pd.DataFrame.sub(SASA_Data_Frame,'columns')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-8fdbd45b1de8> in <module>()
# ----> 1 pd.DataFrame.sub(SASA_Data_Frame,'columns')
#
# /usr/local/anaconda/lib/python2.7/site-packages/pandas/core/ops.pyc in f(self, other, axis, level, fill_value)
#    1233                 self = self.fillna(fill_value)
#    1234
# -> 1235             return self._combine_const(other, na_op)
#    1236
#    1237     f.__name__ = name
#
# /usr/local/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _combine_const(self, other, func, raise_on_error)
#    3623
#    3624         new_data = self._data.eval(func=func, other=other,
# -> 3625                                    raise_on_error=raise_on_error)
#    3626         return self._constructor(new_data)
#    3627
#
# /usr/local/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in eval(self, **kwargs)
#    3160
#    3161     def eval(self, **kwargs):
# -> 3162         return self.apply('eval', **kwargs)
#    3163
#    3164     def quantile(self, **kwargs):
#
# /usr/local/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3054
#    3055             kwargs['mgr'] = self
# -> 3056             applied = getattr(b, f)(**kwargs)
#    3057             result_blocks = _extend_blocks(applied, result_blocks)
#    3058
#
# /usr/local/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in eval(self, func, other, raise_on_error, try_cast, mgr)
#    1164             raise
#    1165         except Exception as detail:
# -> 1166             result = handle_error()
#    1167
#    1168         # technically a broadcast error in numpy can 'work' by returning a
#
# /usr/local/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in handle_error()
#    1147             if raise_on_error:
#    1148                 raise TypeError('Could not operate %s with block values %s' %
# -> 1149                                 (repr(other), str(detail)))
#    1150             else:
#    1151                 # return the values
#
# TypeError: Could not operate 'columns' with block values unsupported operand type(s) for -: 'str' and 'str'

# %%
SASA_Data_Frame.loc[:,('resID','All-atoms-REL')]
# Out:
#     resID All-atoms-REL
# 0       1          54.1
# 1       2          38.3
# 2       3           3.3
# 3       4          48.7
# 4       5           8.5
# 5       6          52.9
# 6       7           0.1
# 7       8          41.6
# 8       9          17.3
# 9      10          20.3
# 10     11          41.9
# 11     12          78.9
# 12     13          34.1
# 13     14           0.2
# 14     15          34.9
# 15     16          13.8
# 16     17           3.6
# 17     18          14.9
# 18     19           0.1
# 19     20          39.7
# 20     21           0.0
# 21     22          32.1
# 22     23           0.0
# 23     24          12.0
# 24     25          41.3
# 25     26          73.2
# 26     27          59.2
# 27     28          17.9
# 28     29          47.0
# 29     30           0.2
# ..    ...           ...
# 300   301          92.5
# 301   302          19.7
# 302   303          15.4
# 303   304          10.1
# 304   305           0.5
# 305   306           0.0
# 306   307           1.1
# 307   308           0.0
# 308   309           0.0
# 309   310           0.5
# 310   311           1.7
# 311   312          11.3
# 312   313           0.0
# 313   314           0.4
# 314   315           0.1
# 315   316           0.2
# 316   317           0.0
# 317   318          19.4
# 318   319          16.7
# 319   320          35.0
# 320   321         105.2
# 321   322          73.5
# 322   323          13.7
# 323   324          23.3
# 324   325           0.0
# 325   326           0.0
# 326   327           1.0
# 327   328           1.4
# 328   329          41.0
# 329   330          50.0
#
# [330 rows x 2 columns]
